# %%
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# # 1.The Binomial No-Arbitrage Pricing Model

# %% [markdown]
# ## One-Period Binomial Model

# %%
r = np.round(np.random.uniform(1, 2), 2)

u_arr = np.round(np.random.uniform(r+.01, u, 100), 2)
d_arr = np.round(np.random.uniform(1.0, r-.01, 100), 2)

# %%
fig, ax = plt.subplots(1, figsize=(21, 5))
ax.plot(np.arange(100), u_arr, marker='o', label='up factor')
ax.plot(np.arange(100), d_arr, marker='o', label='down factor')
ax.hlines(r, 0, 99, label='rate of return', color='r')
ax.set_title('Tossed a Coin with no-arbitrage')
ax.legend()
